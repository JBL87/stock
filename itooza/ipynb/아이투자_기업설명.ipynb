# %%
import importlib, sys
sys.path.append(r"C:\Users\bong2\OneDrive\Python_Codes\00_python_scripts") # script 경로 window용

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 100)  

import pandas as pd
import requests
from bs4 import BeautifulSoup
import conn_db
import helper
user_agent = helper.user_agent
import stock_itooza_cleaner, stock_itooza_updater
# Out:
# <style>.container { width:100% !important; }</style>

# %%
importlib.reload(stock_itooza_updater)
# Out:
# <module 'stock_itooza_updater' from 'C:\\Users\\bong2\\OneDrive\\Python_Codes\\00_python_scripts\\stock_itooza_updater.py'>

# %%
code_list = conn_db.from_("DB_기업정보", 'FS_update_list')[['종목코드','종목명']]

# %%
company_description = pd.DataFrame()

# %%
new = code_list['종목코드']
old = conn_db.from_("DB_기업정보", 'from_아이투자_기업정보')['종목코드']
new_code_list = list(set(new) - set(old))

# %%
new_code_list
# Out:
# ['257720', '260970', '377220', '099430']

# %%
stock_itooza_updater.update_itooza_company_description('all')
# Out:
# ------------------------------
# update_itooza_company_description     시작: 21-10-04 14:44
# C:\Users\bong2\OneDrive\Python_Codes\00_python_scripts\stock_itooza_updater.py:221: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['기준날짜'] = df['기준날짜'].astype(str).str.replace('.', '/')
# 098120 완료
# 009520 완료
# 095570 완료
# 006840 완료
# 282330 완료
# 027410 완료
# 138930 완료
# 001460 완료
# 001040 완료
# 011150 완료
# 058820 완료
# 000590 완료
# 012030 완료
# 016610 완료
# 005830 완료
# 000990 완료
# 139130 완료
# 001530 완료
# 001880 완료
# 000210 완료
# 375500 완료
# 155660 완료
# 069730 완료
# 017940 완료
# 050120 완료
# 383220 완료
# 007700 완료
# 006360 완료
# 078930 완료
# 012630 완료
# 294870 완료
# 003560 완료
# 175330 완료
# 234080 완료
# 001060 완료
# 096760 완료
# 105560 완료
# 024120 완료
# 009070 완료
# 016380 완료
# 001390 완료
# 033180 완료
# 001940 완료
# 025000 완료
# 092230 완료
# 000040 완료
# ...
